# %%
import os
import random
from PIL import Image
import zipfile

# %%
with zipfile.ZipFile("Project.zip", 'r') as zip_ref:
    zip_ref.extractall()

# %%
with zipfile.ZipFile("Trees.zip", 'r') as zip_ref:
    zip_ref.extractall()

# %%
image_folder = "Project/Merged_Dataset/images"
label_folder = "Project/Merged_Dataset/labels"
tree_folder = "Trees"
output_folder = "Occlusion_Output"

# Make sure output directory exists
os.makedirs(output_folder, exist_ok=True)

# %%
import os
import random
from PIL import Image

# === CONFIGURATION ===
image_folder = "Project/Merged_Dataset/images"
label_folder = "Project/Merged_Dataset/labels"
tree_folder = "Trees"
output_folder = "output3"

# Ensure output folder exists
os.makedirs(output_folder, exist_ok=True)

# Load all tree PNGs
tree_paths = [os.path.join(tree_folder, f) for f in os.listdir(tree_folder) if f.endswith(".png")]
trees = [Image.open(p).convert("RGBA") for p in tree_paths]

if not trees:
    raise Exception("No tree PNGs found!")

print(f"Loaded {len(trees)} tree images.")

# Handle resampling across Pillow versions
try:
    resample = Image.Resampling.LANCZOS
except AttributeError:
    resample = Image.ANTIALIAS

# Process each image
image_files = [f for f in os.listdir(image_folder) if f.lower().endswith((".jpg", ".jpeg", ".png"))]

for image_name in image_files:
    image_path = os.path.join(image_folder, image_name)
    label_path = os.path.join(label_folder, os.path.splitext(image_name)[0] + ".txt")

    if not os.path.exists(label_path):
        print(f"Skipping {image_name}: no annotation file")
        continue

    # Open image
    base_img = Image.open(image_path).convert("RGBA")
    img_width, img_height = base_img.size

    # Read annotations
    with open(label_path, 'r') as f:
        lines = f.readlines()

    for line in lines:
        parts = line.strip().split()
        if len(parts) != 5:
            continue

        class_id, x_center, y_center, width, height = map(float, parts)

        # Convert normalized YOLO coordinates to pixel values
        box_w = int(width * img_width)
        box_h = int(height * img_height)
        x1 = int((x_center - width / 2) * img_width)
        y1 = int((y_center - height / 2) * img_height)

        # Load and scale tree
        base_tree = random.choice(trees).copy()
        scale_factor = random.uniform(1.5, 3.5)

        tree_w, tree_h = base_tree.size
        aspect_ratio = tree_w / tree_h
        max_dim = int(max(box_w, box_h) * scale_factor)

        if aspect_ratio > 1:
            new_w = max_dim
            new_h = int(max_dim / aspect_ratio)
        else:
            new_h = max_dim
            new_w = int(max_dim * aspect_ratio)

        tree_img = base_tree.resize((new_w, new_h), resample)
        tree_img = tree_img.rotate(random.choice([0, 90, 180, 270]), expand=True)

        # CENTERED placement over car
        paste_x = x1 + (box_w - new_w) // 2
        paste_y = y1 + (box_h - new_h) // 2

        # Clip to image bounds
        paste_x = max(0, min(paste_x, img_width - new_w))
        paste_y = max(0, min(paste_y, img_height - new_h))

        # Paste with transparency
        base_img.paste(tree_img, (paste_x, paste_y), tree_img)

    # Save the final image
    out_path = os.path.join(output_folder, image_name)
    base_img.convert("RGB").save(out_path)
    print(f"Saved: {out_path}")
# Out:
# Loaded 11 tree images.
# ✅ Saved: output3/2 (34)_1650425225_aug0.jpg
# ✅ Saved: output3/1 (19)_1649990929.jpg
# ✅ Saved: output3/2013-02-22_17_10_11_aug0.jpg
# ✅ Saved: output3/steptodown.com393941_aug0.jpg
# ✅ Saved: output3/21_aug0.jpg
# ✅ Saved: output3/steptodown.com694149_aug2.jpg
# ✅ Saved: output3/steptodown.com782779_aug0.jpg
# ✅ Saved: output3/20_aug1.jpg
# ✅ Saved: output3/4 (27)_1649991515_aug1.jpg
# ✅ Saved: output3/steptodown.com106658_aug0.jpg
# ✅ Saved: output3/2 (34)_1650425225_aug1.jpg
# ✅ Saved: output3/2 (50)_1650423534_aug1.jpg
# ✅ Saved: output3/4 (12)_1649859974_aug0.jpg
# ✅ Saved: output3/1 (34)_1650425207_aug1.jpg
# ✅ Saved: output3/2_aug2.jpg
# ✅ Saved: output3/4 (19)_1649991443_aug0.jpg
# ✅ Saved: output3/steptodown.com777376.jpg
# ✅ Saved: output3/steptodown.com828042.jpg
# ✅ Saved: output3/steptodown.com893372_aug1.jpg
# ✅ Saved: output3/5 (24)_1649991661_aug2.jpg
# ✅ Saved: output3/4_aug1.jpg
# ✅ Saved: output3/4 (12)_1649859974_aug1.jpg
# ✅ Saved: output3/3 (49)_1650423576_aug2.jpg
# ✅ Saved: output3/3 (10)_1649859853_aug2.jpg
# ✅ Saved: output3/5 (5)_1649860045.jpg
# ✅ Saved: output3/2 (25)_1649991086_aug1.jpg
# ✅ Saved: output3/30.png
# ✅ Saved: output3/steptodown.com849356_aug0.jpg
# ✅ Saved: output3/1 (50)_1650423524_aug2.jpg
# ✅ Saved: output3/21_aug1.jpg
# ✅ Saved: output3/steptodown.com777376_aug0.jpg
# ✅ Saved: output3/4 (17)_1649991424_aug0.jpg
# ✅ Saved: output3/2 (23)_1649991063_aug1.jpg
# ✅ Saved: output3/15.png
# ✅ Saved: output3/steptodown.com393941_aug1.jpg
# ✅ Saved: output3/steptodown.com104484_aug1.jpg
# ✅ Saved: output3/1 (25)_1649990957_aug2.jpg
# ✅ Saved: output3/4 (13)_1649859983_aug0.jpg
# ✅ Saved: output3/2 (21)_1649991057_aug0.jpg
# ✅ Saved: output3/4 (19)_1649991443_aug2.jpg
# ✅ Saved: output3/30_aug2.jpg
# ✅ Saved: output3/img_1006075057_aug0.jpg
# ✅ Saved: output3/3 (50)_1650423538_aug0.jpg
# ✅ Saved: output3/steptodown.com736859_aug2.jpg
# ✅ Saved: output3/steptodown.com393941.jpg
# ✅ Saved: output3/4 (13)_1649859983_aug2.jpg
# ✅ Saved: output3/8_aug1.jpg
# ✅ Saved: output3/steptodown.com401585_aug1.jpg
# ✅ Saved: output3/1 (50)_1650423524_aug1.jpg
# ✅ Saved: output3/steptodown.com777376_aug1.jpg
# ✅ Saved: output3/5 (23)_1649991655_aug0.jpg
# ✅ Saved: output3/2 (26)_1649991093_aug2.jpg
# ✅ Saved: output3/2 (34)_1650425225_aug2.jpg
# ✅ Saved: output3/1 (46)_1650423860_aug2.jpg
# ✅ Saved: output3/31_aug2.jpg
# ✅ Saved: output3/1 (46)_1650423860_aug1.jpg
# ✅ Saved: output3/2013-02-22_17_10_11_aug2.jpg
# ✅ Saved: output3/18.png
# ✅ Saved: output3/17_aug2.jpg
# ✅ Saved: output3/17_aug1.jpg
# ✅ Saved: output3/4 (19)_1649991443_aug1.jpg
# ✅ Saved: output3/steptodown.com948028.jpg
# ✅ Saved: output3/2 (21)_1649991057.jpg
# ✅ Saved: output3/4 (18)_1649991433_aug0.jpg
# ✅ Saved: output3/4 (13)_1649859983_aug1.jpg
# ✅ Saved: output3/steptodown.com893372.jpg
# ✅ Saved: output3/steptodown.com686279_aug0.jpg
# ✅ Saved: output3/5_aug0.jpg
# ✅ Saved: output3/1 (34)_1650425207_aug0.jpg
# ✅ Saved: output3/19.png
# ✅ Saved: output3/1 (34)_1650425207_aug2.jpg
# ✅ Saved: output3/15_aug1.jpg
# ✅ Saved: output3/steptodown.com646039_aug1.jpg
# ✅ Saved: output3/2 (10)_1649859717_aug0.jpg
# ✅ Saved: output3/steptodown.com401585_aug0.jpg
# ✅ Saved: output3/4 (27)_1649991515_aug0.jpg
# ✅ Saved: output3/2 (25)_1649991086_aug2.jpg
# ✅ Saved: output3/10_aug2.jpg
# ✅ Saved: output3/31_aug0.jpg
# ✅ Saved: output3/9.png
# ✅ Saved: output3/2 (26)_1649991093_aug0.jpg
# ✅ Saved: output3/4 (17)_1649991424_aug2.jpg
# ✅ Saved: output3/1_1649857847_aug0.jpg
# ✅ Saved: output3/steptodown.com694149_aug1.jpg
# ✅ Saved: output3/steptodown.com672519_aug1.jpg
# ✅ Saved: output3/11_aug1.jpg
# ✅ Saved: output3/14_aug2.jpg
# ✅ Saved: output3/steptodown.com893372_aug2.jpg
# ✅ Saved: output3/12_aug0.jpg
# ✅ Saved: output3/1_1649857847_aug1.jpg
# ✅ Saved: output3/2 (22)_1649991051.jpg
# ✅ Saved: output3/5 (11)_1649860101_aug0.jpg
# ✅ Saved: output3/steptodown.com401585.jpg
# ✅ Saved: output3/4 (18)_1649991433.jpg
# ✅ Saved: output3/steptodown.com403068_aug1.jpg
# ✅ Saved: output3/img_1006075057_aug2.jpg
# ✅ Saved: output3/steptodown.com672519_aug2.jpg
# ✅ Saved: output3/steptodown.com777376_aug2.jpg
# ✅ Saved: output3/2 (23)_1649991063_aug0.jpg
# ✅ Saved: output3/11.png
# ✅ Saved: output3/30_aug1.jpg
# ✅ Saved: output3/2 (50)_1650423534_aug0.jpg
# ✅ Saved: output3/steptodown.com969775_aug1.jpg
# ✅ Saved: output3/18_aug0.jpg
# ✅ Saved: output3/5 (24)_1649991661_aug0.jpg
# ✅ Saved: output3/5 (11)_1649860101_aug1.jpg
# ✅ Saved: output3/steptodown.com674193.jpg
# ✅ Saved: output3/21_aug2.jpg
# ✅ Saved: output3/6 (40)_1650424329_aug1.jpg
# ✅ Saved: output3/steptodown.com401585_aug2.jpg
# ✅ Saved: output3/steptodown.com969775.jpg
# ✅ Saved: output3/img_1006075057_aug1.jpg
# ✅ Saved: output3/3 (50)_1650423538.jpg
# ✅ Saved: output3/1 (19)_1649990929_aug1.jpg
# ✅ Saved: output3/2 (31)_1650425646_aug1.jpg
# ✅ Saved: output3/2 (42)_1650424237.jpg
# ✅ Saved: output3/2013-02-22_17_10_11.jpg
# ✅ Saved: output3/2 (26)_1649991093_aug1.jpg
# ✅ Saved: output3/3 (50)_1650423538_aug1.jpg
# ✅ Saved: output3/8_aug2.jpg
# ✅ Saved: output3/17.png
# ✅ Saved: output3/steptodown.com253027_aug1.jpg
# ✅ Saved: output3/2 (25)_1649991086_aug0.jpg
# ✅ Saved: output3/2 (42)_1650424237_aug2.jpg
# ✅ Saved: output3/steptodown.com782779_aug2.jpg
# ✅ Saved: output3/steptodown.com106658.jpg
# ✅ Saved: output3/14_aug0.jpg
# ✅ Saved: output3/6 (40)_1650424329.jpg
# ✅ Saved: output3/1 (50)_1650423524.jpg
# ✅ Saved: output3/17_aug0.jpg
# ✅ Saved: output3/4 (17)_1649991424.jpg
# ✅ Saved: output3/25_aug0.jpg
# ✅ Saved: output3/2_aug1.jpg
# ✅ Saved: output3/15_aug0.jpg
# ✅ Saved: output3/2013-02-22_17_10_11_aug1.jpg
# ✅ Saved: output3/steptodown.com728076_aug2.jpg
# ✅ Saved: output3/1_1649857847.jpg
# ✅ Saved: output3/2 (31)_1650425646_aug2.jpg
# ✅ Saved: output3/5 (19)_1649991620_aug1.jpg
# ✅ Saved: output3/4 (20)_1649991450_aug2.jpg
# ✅ Saved: output3/11_aug2.jpg
# ✅ Saved: output3/2 (50)_1650423534.jpg
# ✅ Saved: output3/31.png
# ✅ Saved: output3/steptodown.com403068_aug2.jpg
# ✅ Saved: output3/steptodown.com106658_aug2.jpg
# ✅ Saved: output3/2 (23)_1649991063.jpg
# ✅ Saved: output3/5 (23)_1649991655_aug1.jpg
# ✅ Saved: output3/5 (19)_1649991620.jpg
# ✅ Saved: output3/4 (13)_1649859983.jpg
# ✅ Saved: output3/0.png
# ✅ Saved: output3/4 (12)_1649859974_aug2.jpg
# ✅ Saved: output3/4 (27)_1649991515_aug2.jpg
# ✅ Saved: output3/0_aug1.jpg
# ✅ Saved: output3/12.png
# ✅ Saved: output3/steptodown.com790307_aug2.jpg
# ✅ Saved: output3/steptodown.com736859_aug1.jpg
# ✅ Saved: output3/4 (31)_1650425414.jpg
# ✅ Saved: output3/0_aug0.jpg
# ✅ Saved: output3/1 (46)_1650423860_aug0.jpg
# ✅ Saved: output3/5 (11)_1649860101.jpg
# ✅ Saved: output3/steptodown.com686279.jpg
# ✅ Saved: output3/steptodown.com104484.jpg
# ✅ Saved: output3/steptodown.com893372_aug0.jpg
# ✅ Saved: output3/steptodown.com728076_aug0.jpg
# ✅ Saved: output3/steptodown.com736859_aug0.jpg
# ✅ Saved: output3/1 (33)_1650425342_aug0.jpg
# ✅ Saved: output3/10_aug0.jpg
# ✅ Saved: output3/2 (50)_1650423534_aug2.jpg
# ✅ Saved: output3/1 (25)_1649990957_aug1.jpg
# ✅ Saved: output3/5_aug2.jpg
# ✅ Saved: output3/2 (22)_1649991051_aug2.jpg
# ✅ Saved: output3/3 (10)_1649859853.jpg
# ✅ Saved: output3/steptodown.com535976_aug1.jpg
# ✅ Saved: output3/21.png
# ✅ Saved: output3/2 (31)_1650425646.jpg
# ✅ Saved: output3/steptodown.com403068.jpg
# ✅ Saved: output3/steptodown.com969775_aug2.jpg
# ✅ Saved: output3/14_aug1.jpg
# ✅ Saved: output3/4 (18)_1649991433_aug2.jpg
# ✅ Saved: output3/steptodown.com849356_aug1.jpg
# ✅ Saved: output3/5 (5)_1649860045_aug0.jpg
# ✅ Saved: output3/steptodown.com686279_aug1.jpg
# ✅ Saved: output3/9_aug0.jpg
# ✅ Saved: output3/1 (34)_1650425207.jpg
# ✅ Saved: output3/2_aug0.jpg
# ✅ Saved: output3/3 (49)_1650423576_aug1.jpg
# ✅ Saved: output3/18_aug2.jpg
# ✅ Saved: output3/2 (42)_1650424237_aug1.jpg
# ✅ Saved: output3/0_aug2.jpg
# ✅ Saved: output3/1 (33)_1650425342_aug1.jpg
# ✅ Saved: output3/2 (31)_1650425646_aug0.jpg
# ✅ Saved: output3/5 (19)_1649991620_aug2.jpg
# ✅ Saved: output3/1_1649857847_aug2.jpg
# ✅ Saved: output3/5 (11)_1649860101_aug2.jpg
# ✅ Saved: output3/12_aug2.jpg
# ✅ Saved: output3/2 (21)_1649991057_aug2.jpg
# ✅ Saved: output3/2 (30)_1649991125.jpg
# ✅ Saved: output3/steptodown.com849356.jpg
# ✅ Saved: output3/8.png
# ✅ Saved: output3/2 (22)_1649991051_aug0.jpg
# ✅ Saved: output3/1 (39)_1650424507_aug1.jpg
# ✅ Saved: output3/steptodown.com782779.jpg
# ✅ Saved: output3/14.png
# ✅ Saved: output3/2 (10)_1649859717_aug2.jpg
# ✅ Saved: output3/20_aug0.jpg
# ✅ Saved: output3/5.png
# ✅ Saved: output3/1 (19)_1649990929_aug2.jpg
# ✅ Saved: output3/steptodown.com646039.jpg
# ✅ Saved: output3/8_aug0.jpg
# ✅ Saved: output3/20.png
# ✅ Saved: output3/steptodown.com674193_aug2.jpg
# ✅ Saved: output3/4 (19)_1649991443.jpg
# ✅ Saved: output3/2 (26)_1649991093.jpg
# ✅ Saved: output3/1 (39)_1650424507_aug0.jpg
# ✅ Saved: output3/steptodown.com728076.jpg
# ✅ Saved: output3/img_1006075057.jpg
# ✅ Saved: output3/12_aug1.jpg
# ✅ Saved: output3/steptodown.com790307_aug0.jpg
# ✅ Saved: output3/5 (23)_1649991655_aug2.jpg
# ✅ Saved: output3/5 (24)_1649991661.jpg
# ✅ Saved: output3/steptodown.com106658_aug1.jpg
# ✅ Saved: output3/2 (10)_1649859717_aug1.jpg
# ✅ Saved: output3/3 (10)_1649859853_aug1.jpg
# ✅ Saved: output3/steptodown.com403068_aug0.jpg
# ✅ Saved: output3/3_aug0.jpg
# ✅ Saved: output3/steptodown.com104484_aug0.jpg
# ✅ Saved: output3/18_aug1.jpg
# ✅ Saved: output3/2 (23)_1649991063_aug2.jpg
# ✅ Saved: output3/6 (40)_1650424329_aug2.jpg
# ✅ Saved: output3/20_aug2.jpg
# ✅ Saved: output3/4 (31)_1650425414_aug2.jpg
# ✅ Saved: output3/steptodown.com828042_aug2.jpg
# ✅ Saved: output3/steptodown.com948028_aug2.jpg
# ✅ Saved: output3/5 (5)_1649860045_aug1.jpg
# ✅ Saved: output3/5 (5)_1649860045_aug2.jpg
# ✅ Saved: output3/1 (50)_1650423524_aug0.jpg
# ✅ Saved: output3/4.png
# ✅ Saved: output3/5 (19)_1649991620_aug0.jpg
# ✅ Saved: output3/9_aug2.jpg
# ✅ Saved: output3/9_aug1.jpg
# ✅ Saved: output3/steptodown.com828042_aug1.jpg
# ✅ Saved: output3/1 (46)_1650423860.jpg
# ✅ Saved: output3/3.png
# ✅ Saved: output3/steptodown.com828042_aug0.jpg
# ✅ Saved: output3/steptodown.com253027_aug0.jpg
# ✅ Saved: output3/3 (10)_1649859853_aug0.jpg
# ✅ Saved: output3/steptodown.com782779_aug1.jpg
# ✅ Saved: output3/steptodown.com646039_aug2.jpg
# ✅ Saved: output3/4 (27)_1649991515.jpg
# ✅ Saved: output3/steptodown.com674193_aug0.jpg
# ✅ Saved: output3/steptodown.com969775_aug0.jpg
# ✅ Saved: output3/3 (50)_1650423538_aug2.jpg
# ✅ Saved: output3/steptodown.com694149_aug0.jpg
# ✅ Saved: output3/steptodown.com728076_aug1.jpg
# ✅ Saved: output3/steptodown.com253027.jpg
# ✅ Saved: output3/1 (19)_1649990929_aug0.jpg
# ✅ Saved: output3/31_aug1.jpg
# ✅ Saved: output3/1 (25)_1649990957.jpg
# ✅ Saved: output3/steptodown.com948028_aug1.jpg
# ✅ Saved: output3/3_aug1.jpg
# ✅ Saved: output3/steptodown.com736859.jpg
# ✅ Saved: output3/15_aug2.jpg
# ✅ Saved: output3/11_aug0.jpg
# ✅ Saved: output3/5 (23)_1649991655.jpg
# ✅ Saved: output3/4_aug2.jpg
# ✅ Saved: output3/3 (49)_1650423576.jpg
# ✅ Saved: output3/10_aug1.jpg
# ✅ Saved: output3/steptodown.com672519_aug0.jpg
# ✅ Saved: output3/4 (18)_1649991433_aug1.jpg
# ✅ Saved: output3/steptodown.com790307_aug1.jpg
# ✅ Saved: output3/steptodown.com646039_aug0.jpg
# ✅ Saved: output3/steptodown.com535976.jpg
# ✅ Saved: output3/2 (42)_1650424237_aug0.jpg
# ✅ Saved: output3/5_aug1.jpg
# ✅ Saved: output3/1 (39)_1650424507.jpg
# ✅ Saved: output3/4 (17)_1649991424_aug1.jpg
# ✅ Saved: output3/2 (10)_1649859717.jpg
# ✅ Saved: output3/steptodown.com672519.jpg
# ✅ Saved: output3/4 (31)_1650425414_aug0.jpg
# ✅ Saved: output3/steptodown.com535976_aug2.jpg
# ✅ Saved: output3/1 (25)_1649990957_aug0.jpg
# ✅ Saved: output3/10.png
# ✅ Saved: output3/6 (40)_1650424329_aug0.jpg
# ✅ Saved: output3/4 (20)_1649991450_aug1.jpg
# ✅ Saved: output3/steptodown.com849356_aug2.jpg
# ✅ Saved: output3/4 (20)_1649991450.jpg
# ✅ Saved: output3/steptodown.com686279_aug2.jpg
# ✅ Saved: output3/3 (49)_1650423576_aug0.jpg
# ✅ Saved: output3/steptodown.com948028_aug0.jpg
# ✅ Saved: output3/steptodown.com790307.jpg
# ✅ Saved: output3/4 (31)_1650425414_aug1.jpg
# ✅ Saved: output3/steptodown.com104484_aug2.jpg
# ✅ Saved: output3/steptodown.com694149.jpg
# ✅ Saved: output3/25_aug2.jpg
# ✅ Saved: output3/4 (20)_1649991450_aug0.jpg
# ✅ Saved: output3/2 (34)_1650425225.jpg
# ✅ Saved: output3/5 (24)_1649991661_aug1.jpg
# ✅ Saved: output3/4_aug0.jpg
# ✅ Saved: output3/25.png
# ✅ Saved: output3/1 (33)_1650425342_aug2.jpg
# ✅ Saved: output3/steptodown.com674193_aug1.jpg
# ✅ Saved: output3/2.png
# ✅ Saved: output3/2 (25)_1649991086.jpg
# ✅ Saved: output3/steptodown.com535976_aug0.jpg
# ✅ Saved: output3/3_aug2.jpg
# ✅ Saved: output3/steptodown.com253027_aug2.jpg
# ✅ Saved: output3/4 (12)_1649859974.jpg
# ✅ Saved: output3/2 (22)_1649991051_aug1.jpg
# ✅ Saved: output3/steptodown.com393941_aug2.jpg
# ✅ Saved: output3/25_aug1.jpg
# ✅ Saved: output3/2 (21)_1649991057_aug1.jpg
# ✅ Saved: output3/1 (33)_1650425342.jpg
# ✅ Saved: output3/30_aug0.jpg
# ✅ Saved: output3/1 (39)_1650424507_aug2.jpg
